# %%
#from PIL import Image
#import pytesseract
#import inspect
import cv2

# %%
image = Image.open("Icard.jpg")
image = image.convert('L')
display(image)
text = pytesseract.image_to_string(image)
print(text)
# Out:
# <PIL.Image.Image image mode=L size=1911x1207 at 0x7FC5E52EDE10>
# wy NORTHERN INDIA ENGINEERING COLLEGE )
# Se 2) Affiliated to GGS Indraprastha
#
# University, Dethi
# (Approved by AICTE, Ministry of HRD, Govt. of india)
# FC-26, Shastri Park, New Delhi-110053 , Ph.: 011-49905900-99
#
# STUDENT IDENTITY CARD
#
# -: 43715602717
#
# Keshav Choudhary
# B.Tech-CSE ist Shift
# : 12/12/1999
# Father's Name : Mr. Murari Choudhary
# Phone No. : 9650285437, 9868305073
# Address : G-61A, 50 Feet Road, Nihal Vihar,
#
# Nangloi West, Delhi-110041
# Blood Group

# %%
img=cv2.imread("Icard.jpg")
cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
